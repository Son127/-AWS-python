# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt

pd_data = pd.read_csv("전국일방통행도로표준데이터.csv", encoding = 'cp949')
column_select = ['시도명', '지정사유', '지정연도', '도로폭', '도로차로수', '보차분리여부']
pd_data = pd_data[column_select]
pd_data
# Out:
#         시도명  지정사유  지정연도  도로폭  도로차로수 보차분리여부
# 0       경기도   NaN   NaN  5.0    1.0      Y
# 1       경기도   NaN   NaN  5.0    1.0      Y
# 2       경기도   NaN   NaN  9.0    1.0      Y
# 3       경기도   NaN   NaN  4.0    1.0      Y
# 4       경기도   NaN   NaN  4.0    1.0      Y
# ...     ...   ...   ...  ...    ...    ...
# 2154    경기도  통행원활   NaN  6.0    1.0      N
# 2155    경기도  통행원활   NaN  6.0    1.0      N
# 2156    경기도  통행원활   NaN  6.0    1.0      N
# 2157    경기도  통행원활   NaN  6.0    1.0      N
# 2158  서울특별시   NaN   NaN  9.5    1.0      N
#
# [2159 rows x 6 columns]

# %%
pd_data.value_count
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In[10], line 1
# ----> 1 pd_data.value_count
#
# File ~\AppData\Local\Programs\Python\Python310\lib\site-packages\pandas\core\generic.py:5902, in NDFrame.__getattr__(self, name)
#    5895 if (
#    5896     name not in self._internal_names_set
#    5897     and name not in self._metadata
#    5898     and name not in self._accessors
#    5899     and self._info_axis._can_hold_identifiers_and_holds_name(name)
#    5900 ):
#    5901     return self[name]
# -> 5902 return object.__getattribute__(self, name)
#
# AttributeError: 'DataFrame' object has no attribute 'value_count'
