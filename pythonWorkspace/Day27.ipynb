# %%
import seaborn as sns
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import matplotlib

current_font_list = matplotlib.rcParams['font.family']
font_path = "C:\Windows\Fonts\gulim.ttc"
kfont = matplotlib.font_manager.FontProperties(fname=font_path).get_name()

matplotlib.rcParams['font.family'] = [kfont] + current_font_list

fig,axe = plt.subplots()
# axe.plot(np.linspace(-1.0,1.0,10),np.sin(np.linspace(-1.0,1.0,10)))
axe.plot(np.sin(np.linspace(-1.0,1.0,10)))

# fig.set_facecolor('blue')
# axe.set_facecolor('red')

axe1 = fig.add_axes([0.2,0.2,0.5,0.5])
axe1.plot([1,2,3,4,5])

# %%
fig1 = plt.figure(layout='tight')
axe1 = fig1.add_subplot(3,2,1)
axe2 =fig1.add_subplot(3,2,2)
axe2 =fig1.add_subplot(3,1,2)
axe2 =fig1.add_subplot(3,1,3)
